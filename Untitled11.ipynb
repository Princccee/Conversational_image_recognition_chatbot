# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install dependencies
# !pip install transformers accelerate torch bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 7.0 MB/s eta 0:00:00
# ...

# %%
import json
import torch
from transformers import (AutoModelForCausalLM,
                         AutoTokenizer,
                         BitsAndBytesConfig,
                         pipeline)

# %%
# !pip install -U bitsandbytes

# %%
# Load the Hugging Face token from config.json
with open("/content/drive/MyDrive/Chatbot/config.json") as config_file:
    config_data = json.load(config_file)
HF_TOKEN = config_data["HF_TOKEN"]

# %%
# Load the model and tokenizer from Hugging Face
model_name = "meta-llama/Llama-2-13b-chat-hf"

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name,
                                          token = HF_TOKEN)

tokenizer.pad_token = tokenizer.eos_token

# %%
model = AutoModelForCausalLM.from_pretrained(model_name,
                                             device_map="auto",
                                             torch_dtype=torch.float16,
                                             quantization_config=bnb_config,
                                             token=HF_TOKEN)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-58-99ce4f021e9f> in <cell line: 1>()
# ----> 1 model = AutoModelForCausalLM.from_pretrained(model_name,
#       2                                              device_map="auto",
#       3                                              torch_dtype=torch.float16,
#       4                                              quantization_config=bnb_config,
#       5                                              token=HF_TOKEN)
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562         elif type(config) in cls._model_mapping.keys():
#     563             model_class = _get_model_class(config, cls._model_mapping)
# --> 564             return model_class.from_pretrained(
# ...

# %%
# Load the pipeline for text generation
text_generator = pipeline("text-generation",
                          model=model,
                          tokenizer=tokenizer,
                          max_new_tokens=512,)

# %%
# Chatbot function
def chat():
    print("Chatbot: Hello! How can I assist you today?")

    while True:
        user_input = input("You: ")

        if user_input.lower() in ["exit", "quit", "bye"]:
            print("Chatbot: Goodbye!")
            break

        response = text_generator(user_input, max_new_tokens=200)[0]['generated_text']
        print(f"Chatbot: {response.strip()}\n")

# %%
chat()
# Out:
# Chatbot: Hello! How can I assist you today?
# You: Where is the capital of India?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-e57ee30c65ef> in <cell line: 1>()
# ----> 1 chat()
#
# <ipython-input-23-2bae89d1905e> in chat()
#      10             break
#      11
# ---> 12         response = text_generator(user_input, max_new_tokens=200)[0]['generated_text']
#      13         print(f"Chatbot: {response.strip()}\n")
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py in __call__(self, text_inputs, **kwargs)
#     260                 return super().__call__(chats, **kwargs)
#     261         else:
# --> 262             return super().__call__(text_inputs, **kwargs)
#     263
#     264     def preprocess(
#
# ...
